# %%
import requests

url = 'https://apewisdom.io/api/v1.0/filter/all-stocks'

try:
    response = requests.get(url)
    response.raise_for_status()

    data = response.json()
    print("Response JSON:")
    print(data)

except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# Response JSON:
# {'count': 952, 'pages': 10, 'current_page': 1, 'results': [{'rank': 1, 'ticker': 'SPY', 'name': 'SPDR S&amp;P 500 ETF Trust', 'mentions': 267, 'upvotes': 1409, 'rank_24h_ago': 2, 'mentions_24h_ago': 186}, {'rank': 2, 'ticker': 'TSLA', 'name': 'Tesla', 'mentions': 201, 'upvotes': 848, 'rank_24h_ago': 1, 'mentions_24h_ago': 229}, {'rank': 3, 'ticker': 'NVDA', 'name': 'NVIDIA', 'mentions': 77, 'upvotes': 534, 'rank_24h_ago': 3, 'mentions_24h_ago': 61}, {'rank': 4, 'ticker': 'WOLF', 'name': 'Wolfspeed', 'mentions': 67, 'upvotes': 667, 'rank_24h_ago': 13, 'mentions_24h_ago': 21}, {'rank': 5, 'ticker': 'EU', 'name': 'enCore Energy', 'mentions': 52, 'upvotes': 482, 'rank_24h_ago': 4, 'mentions_24h_ago': 38}, {'rank': 6, 'ticker': 'HOOD', 'name': 'Robinhood', 'mentions': 45, 'upvotes': 317, 'rank_24h_ago': 8, 'mentions_24h_ago': 15}, {'rank': 7, 'ticker': 'QQQ', 'name': 'Invesco QQQ ETF', 'mentions': 43, 'upvotes': 70, 'rank_24h_ago': 5, 'mentions_24h_ago': 42}, {'rank': 8, 'ticker': 'AM', 'name': 'Antero Midstream', 'mentions': 37, 'upvotes': 148, 'rank_24h_ago': 9, 'mentions_24h_ago': 29}, {'rank': 9, 'ticker': 'MAGA', 'name': 'ETF Series Solutions Trust - Point Bridge GOP Stock Tracker ETF', 'mentions': 36, 'upvotes': 712, 'rank_24h_ago': 15, 'mentions_24h_ago': 23}, {'rank': 10, 'ticker': 'DTE', 'name': 'DTE Energy', 'mentions': 32, 'upvotes': 1018, 'rank_24h_ago': 7, 'mentions_24h_ago': 31}, {'rank': 11, 'ticker': 'WW', 'name': 'Weight Watchers', 'mentions': 27, 'upvotes': 219, 'rank_24h_ago': 30, 'mentions_24h_ago': 12}, {'rank': 12, 'ticker': 'IT', 'name': 'Gartner', 'mentions': 25, 'upvotes': 103, 'rank_24h_ago': 25, 'mentions_24h_ago': 13}, {'rank': 13, 'ticker': 'JD', 'name': 'Jingdong Mall', 'mentions': 25, 'upvotes': 101, 'rank_24h_ago': 17, 'mentions_24h_ago': 16}, {'rank': 14, 'ticker': 'GME', 'name': 'GameStop', 'mentions': 25, 'upvotes': 102, 'rank_24h_ago': 34, 'mentions_24h_ago': 12}, {'rank': 15, 'ticker': 'MSTR', 'name': 'MicroStrategy', 'mentions': 24, 'upvotes': 42, 'rank_24h_ago': 49, 'mentions_24h_ago': 9}, {'rank': 16, 'ticker': 'DJT', 'name': 'Trump Media &amp; Technology Group', 'mentions': 24, 'upvotes': 325, 'rank_24h_ago': 29, 'mentions_24h_ago': 16}, {'rank': 17, 'ticker': 'ICE', 'name': 'Intercontinental Exchange', 'mentions': 23, 'upvotes': 207, 'rank_24h_ago': 27, 'mentions_24h_ago': 15}, {'rank': 18, 'ticker': 'CC', 'name': 'Chemours', 'mentions': 23, 'upvotes': 150, 'rank_24h_ago': 11, 'mentions_24h_ago': 23}, {'rank': 19, 'ticker': 'YOU', 'name': 'CLEAR Secure', 'mentions': 23, 'upvotes': 83, 'rank_24h_ago': 12, 'mentions_24h_ago': 23}, {'rank': 20, 'ticker': 'FOR', 'name': 'Forestar Group', 'mentions': 23, 'upvotes': 217, 'rank_24h_ago': 93, 'mentions_24h_ago': 3}, {'rank': 21, 'ticker': 'ALL', 'name': 'Allstate', 'mentions': 22, 'upvotes': 85, 'rank_24h_ago': 14, 'mentions_24h_ago': 18}, {'rank': 22, 'ticker': 'CAT', 'name': 'Caterpillar', 'mentions': 20, 'upvotes': 30, 'rank_24h_ago': 85, 'mentions_24h_ago': 4}, {'rank': 23, 'ticker': 'VOO', 'name': 'Vanguard S&amp;P 500 ETF', 'mentions': 20, 'upvotes': 74, 'rank_24h_ago': 6, 'mentions_24h_ago': 47}, {'rank': 24, 'ticker': 'LINK', 'name': 'Interlink Electronics', 'mentions': 19, 'upvotes': 21, 'rank_24h_ago': 35, 'mentions_24h_ago': 11}, {'rank': 25, 'ticker': 'WMT', 'name': 'Walmart', 'mentions': 18, 'upvotes': 76, 'rank_24h_ago': 83, 'mentions_24h_ago': 4}, {'rank': 26, 'ticker': 'AMD', 'name': 'AMD', 'mentions': 17, 'upvotes': 52, 'rank_24h_ago': 36, 'mentions_24h_ago': 12}, {'rank': 27, 'ticker': 'ES', 'name': 'Eversource Energy', 'mentions': 16, 'upvotes': 37, 'rank_24h_ago': 37, 'mentions_24h_ago': 13}, {'rank': 28, 'ticker': 'GLD', 'name': 'SSgA Active Trust - SSgA SPDR Gold Shares', 'mentions': 16, 'upvotes': 49, 'rank_24h_ago': 41, 'mentions_24h_ago': 10}, {'rank': 29, 'ticker': 'DIS', 'name': 'Walt Disney', 'mentions': 15, 'upvotes': 6, 'rank_24h_ago': 98, 'mentions_24h_ago': 4}, {'rank': 30, 'ticker': 'DAL', 'name': 'Delta Air Lines', ...

# %%
import pandas as pd
df = pd.DataFrame(data['results'])
df.head()
# Out:
#    rank ticker                        name  mentions  upvotes  rank_24h_ago  \
# 0     1    SPY  SPDR S&amp;P 500 ETF Trust       267     1409             2
# 1     2   TSLA                       Tesla       201      848             1
# 2     3   NVDA                      NVIDIA        77      534             3
# 3     4   WOLF                   Wolfspeed        67      667            13
# 4     5     EU               enCore Energy        52      482             4
#
#    mentions_24h_ago
# 0             186.0
# 1             229.0
# 2              61.0
# 3              21.0
# 4              38.0

# %%
df[['ticker']]
# Out:
#    ticker
# 0     SPY
# 1    TSLA
# 2    NVDA
# 3    WOLF
# 4      EU
# ..    ...
# 95     SF
# 96     MD
# 97    AAA
# 98   LOVE
# 99   INVZ
#
# [100 rows x 1 columns]

# %%
import requests
from bs4 import BeautifulSoup
import yfinance as yf
import re
def get_stock_details(ticker_symbol):

    url = f'https://apewisdom.io/stocks/{ticker_symbol}/'
    response = requests.get(url)
    response.raise_for_status()

    soup = BeautifulSoup(response.content, 'html.parser')
    details_div = soup.find('div', class_='row', style='font-size: 18px; margin-top: 20px; margin-bottom: 10px;')

    if details_div:
        details_text = details_div.get_text(separator="\n").strip()
    else:
        details_text = f"Details div not found for {ticker_symbol}."

    match = re.search(r'keywords: (.*)', details_text)
    if match:
        keywords = match.group(1).split(",")
        keywords = [keyword.strip().replace('"', '') for keyword in keywords]
    else:
        keywords = []
    stock_data = yf.Ticker(ticker_symbol)
    try:
        hist = stock_data.history(period="1d")
        if not hist.empty:
            current_price = hist['Close'].iloc[-1]
        else:
            current_price = 'Price not found'
    except Exception as e:
        current_price = f'Error fetching price: {e}'

    positive_percentage = None
    match = re.search(r'(\d+)% positive comments', details_text)
    if match:
        positive_percentage = int(match.group(1))

    return details_text, current_price, positive_percentage, keywords

# %%
get_stock_details('AAPL')
# Out:
# ('During the last 24H AAPL (Apple) was mentioned 6 times on WallstreetBets by a total of 7 different users.\nApple received 60% positive comments versus 40% negative comments.\nMost comonly the AAPL ticker was associated with the keywords: "planning","move","tsla","goog","earnings"',
#  np.float64(209.27999877929688),
#  60,
#  ['planning', 'move', 'tsla', 'goog', 'earnings'])

# %%
get_stock_details('MSFT')
# Out:
# ('During the last 24H MSFT (Microsoft) was mentioned 8 times on WallstreetBets by a total of 9 different users.\nMicrosoft received 44% positive comments versus 56% negative comments.\nMost comonly the MSFT ticker was associated with the keywords: "puts","nvda","earnings","slowing","down"',
#  np.float64(391.8500061035156),
#  44,
#  ['puts', 'nvda', 'earnings', 'slowing', 'down'])

# %%
get_stock_details('TSLA')
# Out:
# ('During the last 24H TSLA (Tesla) was mentioned 161 times on WallstreetBets by a total of 89 different users.\nTesla received 61% positive comments versus 39% negative comments.\nMost comonly the TSLA ticker was associated with the keywords: "bet","before","calls","spy","buy"',
#  np.float64(284.95001220703125),
#  61,
#  ['bet', 'before', 'calls', 'spy', 'buy'])

# %%
get_stock_details('GOOGL')
# Out:
# ('During the last 24H GOOGL (Alphabet (Google)) was mentioned 9 times on WallstreetBets by a total of 7 different users.\nAlphabet (Google) received 80% positive comments versus 20% negative comments.\nMost comonly the GOOGL ticker was associated with the keywords: "bit","like","goes","monday","dismayed"',
#  np.float64(161.9600067138672),
#  80,
#  ['bit', 'like', 'goes', 'monday', 'dismayed'])

# %%
get_stock_details('SPY')
# Out:
# ('During the last 24H SPY (SPDR S&P 500 ETF Trust\r\n\r\n) was mentioned 197 times on WallstreetBets by a total of 129 different users.\nSPDR S&P 500 ETF Trust\r\n\r\n received 56% positive comments versus 44% negative comments.\nMost comonly the SPY ticker was associated with the keywords: "bet","before","goes","created","banbet"',
#  np.float64(550.6400146484375),
#  56,
#  ['bet', 'before', 'goes', 'created', 'banbet'])

# %%
# for ticker in df['ticker']:
#     print(ticker)
#     print('-----------------------------')
#     # print(get_stock_details(ticker))
#     details, price, positive_pct = get_stock_details(ticker)
#     print(f"\nCurrent stock price: {price}")
#     print(f"Positive Sentiment: {positive_pct}%")
#     print(f"\nSentiment details:\n{details}")
#     print('-----------------------------')

# %%
def fetch_details(ticker):
    details, price, positive_pct, keywords = get_stock_details(ticker)
    return pd.Series({
        'current_price': price,
        'positive_sentiment_pct': positive_pct,
        'sentiment_details': details,
        'keywords': keywords
    })

# %%
df[['current_price', 'positive_sentiment_pct', 'sentiment_details', 'keywords']] = df['ticker'].apply(fetch_details)
# Out:
# ERROR:yfinance:$DM: possibly delisted; no price data found  (period=1d)
# ERROR:yfinance:$BIG: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")
# ERROR:yfinance:$MF: possibly delisted; no price data found  (period=1d)
# ERROR:yfinance:$OG: possibly delisted; no price data found  (period=1d) (Yahoo error = "No data found, symbol may be delisted")

# %%
df[df['mentions']>=10]
# Out:
#     rank ticker                                               name  mentions  \
# 0      1    SPY                         SPDR S&amp;P 500 ETF Trust       267
# 1      2   TSLA                                              Tesla       201
# 2      3   NVDA                                             NVIDIA        77
# 3      4   WOLF                                          Wolfspeed        67
# 4      5     EU                                      enCore Energy        52
# 5      6   HOOD                                          Robinhood        45
# 6      7    QQQ                                    Invesco QQQ ETF        43
# 7      8     AM                                   Antero Midstream        37
# 8      9   MAGA  ETF Series Solutions Trust - Point Bridge GOP ...        36
# 9     10    DTE                                         DTE Energy        32
# 10    11     WW                                    Weight Watchers        27
# 11    12     IT                                            Gartner        25
# 12    13     JD                                      Jingdong Mall        25
# 13    14    GME                                           GameStop        25
# 14    15   MSTR                                      MicroStrategy        24
# 15    16    DJT                 Trump Media &amp; Technology Group        24
# 16    17    ICE                          Intercontinental Exchange        23
# 17    18     CC                                           Chemours        23
# 18    19    YOU                                       CLEAR Secure        23
# 19    20    FOR                                     Forestar Group        23
# 20    21    ALL                                           Allstate        22
# 21    22    CAT                                        Caterpillar        20
# 22    23    VOO                           Vanguard S&amp;P 500 ETF        20
# 23    24   LINK                              Interlink Electronics        19
# 24    25    WMT                                            Walmart        18
# 25    26    AMD                                                AMD        17
# 26    27     ES                                  Eversource Energy        16
# 27    28    GLD          SSgA Active Trust - SSgA SPDR Gold Shares        16
# 28    29    DIS                                        Walt Disney        15
# 29    30    DAL                                    Delta Air Lines        15
# 30    31    MGM                                        MGM Resorts        15
# 31    32   PLTR                                           Palantir        15
# 32    33   BULL                                             Webull        15
# 33    34   GOOG                                  Alphabet (Google)        14
# 34    35   TWLO                                             Twilio        14
# 35    36   TQQQ           ProShares Trust - ProShares UltraPro QQQ        14
# 36    37   AAPL                                              Apple        13
# 37    38   AMZN                                             Amazon        13
# 38    39     IQ                                              iQIYI        13
# 39    40   RDDT                                             Reddit        13
# 40    41     DM                                      Desktop Metal        12
# 41    42   META                          Meta Platforms (Facebook)        12
# 42    43    BYD                                        Boyd Gaming        11
# 43    44    BIG                                           Big Lots        11
# 44    45   MSFT                                          Microsoft        10
# 45    46     IP                                International Paper        10
# 46    47     OR                              Osisko Gold Royalties        10
# 47    48   CVNA                                            Carvana        10
# 48    49  GOOGL                                  Alphabet (Google)        10
# 49    50    LOT                                   Lotus Technology        10
#
#     upvotes  rank_24h_ago  mentions_24h_ago    current_price  \
# 0      1409             2             186.0       550.640015
# 1       848             1             229.0       284.950012
# 2       534             3              61.0       111.010002
# 3       667            13              21.0             3.27
# 4       482             4              38.0              1.6
# 5       317             8              15.0        49.450001
# 6        70             5              42.0       472.559998
# 7       148             9              29.0        16.879999
# 8       712            15              23.0        46.553001
# 9      1018             7              31.0       134.759995
# 10      219            30              12.0              0.4
# 11      103            25              13.0       416.089996
# 12      101            17              16.0        32.529999
# 13      102            34              12.0        27.459999
# 14       42            49               9.0       368.709991
# 15      325            29              16.0        26.139999
# 16      207            27              15.0       163.229996
# 17      150            11              23.0            12.37
# 18       83            12              23.0        25.309999
# 19      217            93               3.0        19.639999
# 20       85            14              18.0       192.910004
# 21       30            85               4.0       306.450012
# 22       74             6              47.0       506.109985
# 23       21            35              11.0              6.5
# 24       76            83               4.0        95.089996
# 25       52            36              12.0        96.650002
# 26       37            37              13.0        57.860001
# 27       49            41              10.0       304.730011
# 28        6            98               4.0        90.279999
# 29       -4            87               4.0        41.580002
# 30      111           129               1.0            31.67
# 31       49            10              25.0       112.779999
# 32      187           122               4.0            17.27
# 33      125            21              16.0       163.850006
# 34       -5           103               3.0            95.07
# 35       42            48              13.0        53.860001
# 36       61            57               7.0       209.279999
# 37       67            20              16.0       188.990005
# 38       32            59               5.0             1.92
# 39       64            73               5.0       118.099998
# 40       76            50               7.0  Price not found
# 41      148            18              14.0        547.27002
# 42       22            31               9.0        68.870003
# 43       34            68               7.0  Price not found
# 44      730            19              14.0       391.850006
# 45      132            16              13.0        47.349998
# 46       60            67               6.0            23.35
# 47       25            39               6.0       237.149994
# 48      133            23              13.0       161.960007
# 49       35            44              11.0            1.324
#
#     positive_sentiment_pct                                  sentiment_details  \
# 0                     56.0  During the last 24H SPY (SPDR S&P 500 ETF Trus...
# 1                     61.0  During the last 24H TSLA (Tesla) was mentioned...
# 2                     60.0  During the last 24H NVDA (NVIDIA) was mentione...
# 3                     68.0  During the last 24H WOLF (Wolfspeed) was menti...
# 4                     36.0  During the last 24H EU (enCore Energy) was men...
# 5                     72.0  During the last 24H HOOD (Robinhood) was menti...
# 6                     50.0  During the last 24H QQQ (Invesco QQQ ETF) was ...
# 7                     75.0  During the last 24H AM (Antero Midstream\r\n) ...
# 8                     80.0  During the last 24H MAGA (ETF Series Solutions...
# 9                     63.0  During the last 24H DTE (DTE Energy\r\n) was m...
# 10                    80.0  During the last 24H WW (Weight Watchers) was m...
# 11                    33.0  During the last 24H IT (Gartner) was mentioned...
# 12                    43.0  During the last 24H JD (Jingdong Mall\r\n) was...
# 13                    64.0  During the last 24H GME (GameStop\r\n) was men...
# 14                    73.0  During the last 24H MSTR (MicroStrategy) was m...
# 15                    78.0  During the last 24H DJT (Trump Media & Technol...
# 16                   100.0  During the last 24H ICE (Intercontinental Exch...
# 17                    15.0  During the last 24H CC (Chemours\r\n) was ment...
# 18                    57.0  During the last 24H YOU (CLEAR Secure) was men...
# 19                    20.0  During the last 24H FOR (Forestar Group\r\n) w...
# 20                    33.0  During the last 24H ALL (Allstate) was mention...
# 21                   100.0  During the last 24H CAT (Caterpillar) was ment...
# 22                    71.0  During the last 24H VOO (Vanguard S&P 500 ETF)...
# 23                     NaN                    Details div not found for LINK.
# 24                   100.0  During the last 24H WMT (Walmart) was mentione...
# 25                    75.0  During the last 24H AMD (AMD) was mentioned 10...
# 26                    60.0  During the last 24H ES (Eversource Energy) was...
# 27                    70.0  During the last 24H GLD (SSgA Active Trust - S...
# 28                     NaN                     Details div not found for DIS.
# 29                   100.0  During the last 24H DAL (Delta Air Lines) was ...
# 30                    57.0  During the last 24H MGM (MGM Resorts\r\n\r\n) ...
# 31                    56.0  During the last 24H PLTR (Palantir) was mentio...
# 32                    75.0  During the last 24H BULL (Webull) was mentione...
# 33                    80.0  During the last 24H GOOG (Alphabet (Google)) w...
# 34                     NaN                    Details div not found for TWLO.
# 35                    71.0  During the last 24H TQQQ (ProShares Trust - Pr...
# 36                    60.0  During the last 24H AAPL (Apple) was mentioned...
# 37                    75.0  During the last 24H AMZN (Amazon) was mentione...
# 38                   100.0  During the last 24H IQ (iQIYI) was mentioned 1...
# 39                    60.0  During the last 24H RDDT (Reddit) was mentione...
# 40                   100.0  During the last 24H DM (Desktop Metal) was men...
# 41                    78.0  During the last 24H META (Meta Platforms (Face...
# 42                   100.0  During the last 24H BYD (Boyd Gaming\r\n) was ...
# 43                    67.0  During the last 24H BIG (Big Lots\r\n) was men...
# 44                    44.0  During the last 24H MSFT (Microsoft) was menti...
# 45                   100.0  During the last 24H IP (International Paper\r\...
# 46                    44.0  During the last 24H OR (Osisko Gold Royalties\...
# 47                    80.0  During the last 24H CVNA (Carvana) was mention...
# 48                    80.0  During the last 24H GOOGL (Alphabet (Google)) ...
# 49                    25.0  During the last 24H LOT (Lotus Technology) was...
#
#                                           keywords
# 0             [bet, before, goes, created, banbet]
# 1                   [bet, before, calls, spy, buy]
# 2                  [like, bet, before, img, emote]
# 3            [serious, large, play, happening, re]
# 4      [china, deals, expect, retaliation, others]
# 5          [earnings, calls, before, bullish, img]
# 6                       [dal, dis, twlo, cat, spy]
# 7                [before, goes, edt, record, wins]
# 8               [ashes, fck, yeah, turning, putin]
# 9                     [calls, far, puts, spy, otm]
# 10         [rebound, nicely, next, really, before]
# 11                 [img, emote, wrong, goes, down]
# 12                  [kill, why, vance, major, war]
# 13                            [options, isn, bull]
# 14                  [calls, bet, img, emote, like]
# 15             [like, calls, imagine, naked, keep]
# 16           [jensen, huang, detained, door, open]
# 17         [spending, like, crazy, companies, far]
# 18          [people, img, clutching, poots, thank]
# 19  [bonanza, america, external, revenue, service]
# 20       [writings, more, external, debt, daytona]
# 21          [most, important, earnings, qqq, twlo]
# 22             [re, still, buy, invest, something]
# 23                                              []
# 24  [only, tariff, hahahaha, restarted, shipments]
# 25        [long, term, probably, angelbeatz, made]
# 26   [approaching, major, resistance, nq, futures]
# 27                 [calls, puts, spy, buy, months]
# 28                                              []
# 29                    [wmt, spy, dis, qqq, bought]
# 30               [puts, earnings, dpz, should, ve]
# 31                 [calls, mstr, hood, meta, tech]
# 32                  [next, calls, ipo, img, title]
# 33          [earnings, stock, flat, missed, cloud]
# 34                                              []
# 35                      [like, long, ll, buy, spy]
# 36          [planning, move, tsla, goog, earnings]
# 37          [pumps, reason, rddt, tanks, earnings]
# 38           [years, mental, health, much, better]
# 39   [numbers, upgrade, advertising, isn, hurting]
# 40                                        [access]
# 41                    [rddt, calls, yet, goes, up]
# 42     [tesla, most, important, subsidies, demand]
# 43           [beautiful, bill, big, work, contain]
# 44           [puts, nvda, earnings, slowing, down]
# 45                                              []
# 46   [money, seconds, minutes, become, millionare]
# 47                   [bet, before, pm, like, tsla]
# 48             [bit, like, goes, monday, dismayed]
# 49                             [lost, money, puts]
